# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml (from pandas_datareader)
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas_datareader) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas_datareader) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2025.10.5)
# Requirement already satisfied: six>=1.5 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 881.7 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/4.0 MB 881.7 kB/s eta 0:00:04
#    ------- -------------------------------- 0.8/4.0 MB 865.3 kB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/4.0 MB 871.6 kB/s eta 0:00:04
#    ------------- -------------------------- 1.3/4.0 MB 906.9 kB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 906.9 kB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.0 MB 942.9 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 933.2 kB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.0 MB 916.5 kB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.0 MB 916.5 kB/s eta 0:00:03
#    ----------------------- ---------------- 2.4/4.0 MB 886.7 kB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 908.2 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 928.4 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 928.4 kB/s eta 0:00:02
#    ------------------------------- -------- 3.1/4.0 MB 944.7 kB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 958.1 kB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 969.4 kB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 985.5 kB/s eta 0:00:00
# Installing collected packages: lxml, pandas_datareader
# Successfully installed lxml-6.0.2 pandas_datareader-0.10.0
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas_datareader) (6.0.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas_datareader) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas_datareader) (2.32.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2025.10.5)
# Requirement already satisfied: six>=1.5 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas_datareader as data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# C:\Users\hawsh\AppData\Local\Temp\ipykernel_5000\2487901451.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    31.768665    34.579214    26.258096    28.358113    855215656
# 2007-10-08    30.142330    32.842350    29.952854    32.842350    126671715
# 2007-10-09    32.194981    32.479192    28.531795    30.158122    116725709
# 2007-10-10    32.494995    33.158159    32.210783    33.031841     67931378
# 2007-10-11    36.126595    37.895030    32.210777    37.895030    106320954

# %%
df.shape
# Out:
# (4208, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4208 entries, 2007-10-05 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4208 non-null   float64
#  1   (High, POWERGRID.NS)    4208 non-null   float64
#  2   (Low, POWERGRID.NS)     4208 non-null   float64
#  3   (Open, POWERGRID.NS)    4208 non-null   float64
#  4   (Volume, POWERGRID.NS)  4208 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 197.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4208.000000  4208.000000  4208.000000  4208.000000  4.208000e+03
# mean      78.234866    79.251475    77.230399    78.271021  1.188963e+07
# std       63.502199    64.244905    62.711075    63.483855  2.061999e+07
# min       18.548225    19.827413    16.629444    19.731474  0.000000e+00
# 25%       35.657290    36.219835    35.130677    35.693797  4.799653e+06
# 50%       54.180204    54.805795    53.455116    54.284236  8.344398e+06
# 75%       81.129343    82.097736    80.167315    81.151422  1.362032e+07
# max      354.580750   355.356950   346.576122   353.222365  8.552157e+08

# %%
df = df.reset_index()

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()
# Out:
#     Price  index        Date               Close                High  \
# 0  Ticker    NaN         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0    0.0  2007-10-05  31.768665313720703  34.579213879866685
# 2       1    1.0  2007-10-08  30.142330169677734   32.84235001518121
# 3       2    2.0  2007-10-09   32.19498062133789   32.47919237121999
# 4       3    3.0  2007-10-10    32.4949951171875   33.15815898214266
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  26.258096178340235  28.358113128456118     855215656
# 2  29.952854266217905   32.84235001518121     126671715
# 3  28.531795058412545   30.15812189464917     116725709
# 4   32.21078325597869  33.031840933693566      67931378

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from plotly) (25.0)
# Using cached plotly-6.3.1-py3-none-any.whl (9.8 MB)
# Using cached narwhals-2.7.0-py3-none-any.whl (412 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.7.0 plotly-6.3.1
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (6.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\hawsh\appdata\local\programs\python\python313\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objects as go

# %%
# Candlesticks 
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'], 
                                    high = data01['High'],
                                    low = data01['Low'], 
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
print(df.columns)
# Out:
# MultiIndex([( 'index',             ''),
#             (  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
columns_to_drop = [col for col in ['Date', 'Adj Close'] if col in df.columns]
df = df.drop(columns=columns_to_drop)
# Out:
# C:\Users\hawsh\AppData\Local\Temp\ipykernel_5000\1885138874.py:2: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

# %%
df.head()
# Out:
# Price  index      Close       High        Low       Open     Volume
# 0          0  31.768665  34.579214  26.258096  28.358113  855215656
# 1          1  30.142330  32.842350  29.952854  32.842350  126671715
# 2          2  32.194981  32.479192  28.531795  30.158122  116725709
# 3          3  32.494995  33.158159  32.210783  33.031841   67931378
# 4          4  36.126595  37.895030  32.210777  37.895030  106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 4203    323.594428
# 4204    323.834958
# 4205    324.069895
# 4206    324.268579
# 4207    324.404424
# Name: Close, Length: 4208, dtype: float64

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2945, 1)

# %%
data_testing.shape
# Out:
# (1263, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808599],
#        [0.1737181 ],
#        [0.20447361],
#        ...,
#        [0.90774446],
#        [0.86000367],
#        [0.87299655]], shape=(2945, 1))

# %%
data_training_array.shape[0]
# Out:
# 2945

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2845, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# C:\Users\hawsh\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 104ms/step - loss: 0.0352
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - loss: 0.0093
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 0.0079
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - loss: 0.0070
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0059
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - loss: 0.0059
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - loss: 0.0055
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0050
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - loss: 0.0049
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - loss: 0.0049
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0046
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0046
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0041
# Epoch 14/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0043
# Epoch 15/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0039
# Epoch 16/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0038
# Epoch 17/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0036
# Epoch 18/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0036
# Epoch 19/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 109ms/step - loss: 0.0032
# Epoch 20/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0032
# Epoch 21/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0033
# Epoch 22/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - loss: 0.0032
# Epoch 23/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0030
# Epoch 24/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0031
# Epoch 25/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - loss: 0.0028
# Epoch 26/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 0.0027
# Epoch 27/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - loss: 0.0027
# Epoch 28/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - loss: 0.0028
# Epoch 29/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0024
# Epoch 30/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - loss: 0.0028
# Epoch 31/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0025
# Epoch 32/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - loss: 0.0025
# Epoch 33/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0026
# Epoch 34/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0025
# Epoch 35/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0024
# Epoch 36/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0025
# Epoch 37/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0025
# Epoch 38/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0022
# Epoch 39/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0025
# Epoch 40/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 0.0026
# Epoch 41/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 0.0023
# Epoch 42/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0026
# Epoch 43/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - loss: 0.0023
# Epoch 44/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - loss: 0.0023
# Epoch 45/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - loss: 0.0022
# Epoch 46/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0024
# Epoch 47/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 106ms/step - loss: 0.0023
# Epoch 48/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - loss: 0.0024
# Epoch 49/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - loss: 0.0023
# Epoch 50/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - loss: 0.0025

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#        Close
# 0  74.289238
# 1  75.803711
# 2  76.062775
# 3  75.903358
# 4  76.341759

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1263, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step

# %%
y_predicted.shape
# Out:
# (1263, 1)

# %%
scaler.scale_
# Out:
# array([0.00339787])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('my_model.keras')
